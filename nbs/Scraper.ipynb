# %% [markdown]
# # Scraping Raw Data From Stack Overflow
#
# Systematically extracting business intelligence from data.

# %%
# get inline, interactivate plots
# %matplotlib inline

# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # What is our question?

# %% [markdown]
# Essentially: What are the biggest problem areas for Python programmers?

# %% [markdown]
# # Identify the data (Stack Overflow)

# %% [markdown]
# Data Source: All the questions on Stack Overflow that have the "Python" tag on them.
#
# Question: Where exactly does all of this data live -- what is the URL structure we can use to
# acquire all of this user data?
#
# Task: Work the URL into a formattable string you can feed into a srcaper.

# %%
SO_URL_format = "https://stackoverflow.com/questions/tagged/python?page={0}&sort=frequent&pagesize=50"

# %% [markdown]
# ## Acquire the raw data

# %%
number_of_pages_to_gather = 50

# create sequence of page
page_range = range(1, number_of_pages_to_gather + 1)

# %% [raw]
# So you may have noticed when we were formatting the URL that there are actually 1000s of pages of Python questions,
# but here we're only collecting 50. This is intentional and temporary. Eventually we should collect the entire corpus of data, but right now we are trying to prototype a workflow.  So we are going to temporarily "downsample" to more rapidly prototype.
#
# As a matter of fact, 50 is pretty high.  Let's kick it down to 5 files.  That way, we are still coding with the for conditions where we need to take multiple files (as opposed to just one), but not introducing lots of computing time.

# %%
page_range = range(1, 6)

# %%
# TODO: MAKE A PAGE URLS GENERATOR (argument: array of numbers, yields URLs )

# %%
import requests 

def http_get (URL):
    response = requests.get(URL)
    return response

# 
#  Once you have the data, it can be helpful to comment the following loop out.
# 
# for i in page_range:
#     print("you don't have wifi right now so don't erase ur data")
#     so_page_url = SO_URL_format.format(i)

#     so_response = get(so_page_url)
    
#     if so_response.status_code == 200:
#         html_file = open('FILENAME_00{0}.html'.format(i),'w')
#         html_file.write(so_response.text)
#         html_file.close()
#     else:
#         raise Error

# %% [markdown]
# ## Mash Until No Good! Data Munging/Wrangling/Transforming

# %% [markdown]
# > Bad programmers worry about the code.
# >
# > Good programmers worry about data structures and their relationships.
# >
# > Linus Torvalds, creator of Linux and git

# %% [markdown]
# > I be in the kitchen whipping
# >
# > trying to cook the sauce.
# >
# >   Yo Gotti, _The Art of the Hustle_

# %% [markdown]
# We are not going to begin whipping this data into shape for various levels of analysis - it's hard to do
# analysis on a bunch of data locked up in an HTML structure though.

# %% [markdown]
# #### Extracting the maximum number of dimensions from the data

# %% [markdown]
# Look at the stack overflow page and think about what our granular data points are.  For the pages
# we have decided to
#
# < INSERT PICTURE OF SO PAGE HERE >
#
# The granular logical data point is a question.  So what are the dimensions/attributes of a question object?
# - question text
# - vote score
# - views
# - details
# - author
# - question details
#
# Beautiful soup parses the HTML into a Python tree structure (DOM).  You can then use a variety of BS4 methods to extract specific HTML elements based on HTML attritbute.  Since classes and IDs are HTML attributes, you can use CSS selectors to extract information.

# %%
# insert quick BS4 demo before doing the real code in the next block

# %% [markdown]
# OK, let's actually get the question text, vote score, views, etc. out of the data.

# %%
from bs4 import BeautifulSoup

# %%
for i in page_range:
    file_name = 'FILENAME_00{0}.html'.format(i)
    print(file_name)
    
    with open(file_name,'r') as f:
        soup = BeautifulSoup(f.read(), 'html.parser')
        
        # for each file, get all of the question objects
        questions = soup.find_all("div", class_="question-summary")
        
        for question in questions:
            text = question.find('a', class_="question-hyperlink").text
            tags = [tag.text for tag in question.find_all('a', class_="post-tag")]
            views = int(question.find('div', class_="views")['title'].split(" ")[0].replace(",", ""))
            print(tags)
# Out:
# FILENAME_001.html
# [u'python', u'language-design', u'least-astonishment']
# [u'python', u'if-statement', u'comparison', u'match', u'boolean-logic']
# [u'python', u'list', u'slice']
# [u'python', u'validation', u'loops', u'python-3.x', u'user-input']
# [u'python', u'list', u'nested-lists', u'mutable']
# [u'python', u'list', u'copy', u'clone']
# [u'python', u'variable-variables']
# [u'python', u'list', u'split', u'chunks']
# [u'python', u'reference', u'parameter-passing', u'pass-by-reference']
# [u'python', u'iteration']
# [u'python', u'list', u'multidimensional-array', u'flatten']
# [u'python', u'pandas']
# [u'python', u'python-2.7', u'python-3.x', u'int']
# [u'python', u'iterator', u'generator', u'yield', u'coroutine']
# [u'python', u'scope', u'dynamic-languages']
# [u'python', u'syntax', u'parameter-passing', u'identifier', u'kwargs']
# [u'python', u'shell', u'command', u'subprocess', u'external']
# [u'python', u'module', u'namespaces', u'main', u'idioms']
# [u'python', u'global-variables', u'scope']
# [u'python', u'sorting', u'dictionary']
# [u'python', u'list', u'optimization', u'flatten']
# [u'python', u'oop', u'metaclass', u'python-datamodel']
# [u'python', u'windows', u'installation', u'pip', u'easy-install']
# [u'python', u'int', u'comparison', u'operators', u'identity']
# [u'python', u'python-3.x']
# [u'python', u'dictionary', u'order', u'set', u'python-internals']
# [u'python', u'operators', u'ternary-operator', u'conditional-operator', u'python-2.5']
# [u'python', u'class']
# [u'python', u'decorator', u'python-decorators']
# [u'python', u'multithreading', u'kill', u'terminate']
# [u'python', u'repr']
# [u'python', u'tkinter']
# [u'python', u'eval']
# [u'python', u'boolean', u'boolean-expression']
# [u'python', u'naming-conventions', u'private', u'underscores', u'double-underscore']
# [u'python', u'class', u'oop', u'self']
# [u'python', u'list', u'duplicates', u'unique']
# [u'python', u'windows', u'pip', u'setup.py', u'failed-installation']
# [u'python', u'list-comprehension']
# [u'python', u'string', u'comparison']
# [u'python', u'datetime']
# [u'python', u'class', u'methods', u'static', u'class-variables']
# [u'python', u'windows', u'environment-variables', u'pythonpath']
# [u'python', u'python-2.7', u'python-3.x', u'input', u'nameerror']
# [u'python', u'floating-point', u'integer', u'division', u'python-2.x']
# [u'python', u'list']
# [u'python', u'list', u'loops', u'optimization', u'chunks']
# [u'python', u'iterator']
# [u'python', u'python-3.x', u'dictionary', u'mapping', u'idioms']
# [u'python', u'performance', u'profiling', u'time-complexity']
# FILENAME_002.html
# [u'python', u'class', u'oop', u'types', u'new-style-class']
# [u'python', u'newline']
# [u'python', u'sorting', u'python-3.x']
# [u'python', u'configuration', u'python-import', u'python-module']
# [u'python', u'args', u'kwargs']
# [u'python', u'math', u'optimization', u'primes']
# [u'python', u'exception', u'python-module', u'shadowing']
# [u'python', u'types', u'comparison', u'python-2.x']
# [u'python', u'scope', u'closures', u'nested-function']
# [u'python', u'reference', u'semantics']
# [u'python', u'stdout', u'buffered']
# [u'python', u'io', u'subprocess', u'nonblocking']
# [u'python', u'algorithm', u'permutation', u'combinatorics', u'python-2.5']
# [u'python', u'oop', u'inheritance', u'super']
# [u'python', u'variables']
# [u'python', u'ide', u'editor']
# [u'python', u'list-comprehension', u'map-function']
# [u'python', u'variables', u'scope']
# [u'python', u'file', u'append']
# [u'python', u'unicode', u'rawstring']
# [u'python', u'string']
# [u'python', u'input']
# [u'python', u'sorting', u'dictionary']
# [u'python']
# [u'python', u'dictionary', u'order']
# [u'python', u'python-3.x']
# [u'python', u'unicode']
# [u'python', u'list', u'count']
# [u'python', u'xml']
# [u'python', u'flask', u'static-files']
# [u'python', u'user-interface', u'tkinter']
# [u'python', u'global-variables', u'scope']
# [u'python', u'module']
# [u'python', u'regex', u'search', u'match']
# [u'python', u'lambda', u'closures']
# [u'python', u'linux', u'subprocess', u'kill-process']
# [u'python', u'performance', u'logging', u'string-formatting']
# [u'python', u'python-import', u'python-module']
# [u'python', u'list-comprehension']
# [u'python', u'directory']
# [u'python']
# [u'python', u'python-3.x', u'enums']
# [u'python', u'python-2.7', u'dictionary']
# [u'python', u'performance', u'optimization', u'time-complexity']
# [u'python', u'unicode', u'beautifulsoup', u'python-2.x', u'python-unicode']
# [u'python', u'json', u'parsing']
# [u'python', u'variables', u'naming-conventions', u'underscores', u'metasyntactic-variable']
# [u'python', u'subprocess']
# [u'python', u'virtualenv', u'virtualenvwrapper']
# [u'python', u'string']
# FILENAME_003.html
# [u'python', u'string', u'punctuation']
# [u'python', u'algorithm', u'list', u'duplicates', u'intersection']
# [u'python', u'string', u'list']
# [u'python', u'stdout']
# [u'python', u'datetime', u'utc']
# [u'python', u'math', u'python-2.x']
# [u'python', u'casting', u'floating-point', u'type-conversion']
# [u'python', u'printing', u'flush']
# [u'python', u'pandas', u'dataframe', u'chained-assignment']
# [u'python', u'global-variables', u'side-effects']
# [u'python', u'multithreading']
# [u'python', u'unicode', u'terminal', u'ansi-colors']
# [u'python', u'floating-point', u'rounding', u'precision']
# [u'python', u'list', u'sorting', u'dictionary', u'data-structures']
# [u'python', u'licensing', u'obfuscation', u'copy-protection']
# [u'python', u'python-import']
# [u'python', u'arrays', u'immutability']
# [u'python', u'loops', u'list']
# [u'python', u'multiple-inheritance']
# [u'python', u'global-variables']
# [u'python', u'attributes']
# [u'python', u'module', u'reload', u'python-import']
# [u'python', u'combinations']
# [u'python', u'html', u'html-entities']
# [u'python', u'math']
# [u'python', u'multithreading', u'timeout', u'python-multithreading']
# [u'python', u'shell', u'shebang']
# [u'python', u'relative-path', u'python-import']
# [u'python', u'oop', u'methods', u'monkeypatching']
# [u'python', u'string', u'split']
# [u'python', u'kwargs']
# [u'python', u'http', u'urllib']
# [u'python', u'string', u'parsing', u'floating-point', u'integer']
# [u'python', u'file', u'pywin32', u'watch']
# [u'python', u'list', u'split', u'text-segmentation']
# [u'python', u'file', u'filesystems']
# [u'python', u'dictionary']
# [u'python', u'string', u'unicode', u'binary']
# [u'python', u'algorithm']
# [u'python', u'list', u'data-structures', u'append', u'extend']
# [u'python', u'performance', u'memory-management', u'profiling']
# [u'python', u'stdin']
# [u'python', u'circular-dependency', u'cyclic-reference']
# [u'python', u'python-3.x', u'tkinter', u'frame']
# [u'python', u'mysql']
# [u'python', u'list', u'tuples']
# [u'python', u'command-line', u'command-line-arguments']
# [u'python', u'pandas', u'group-by', u'pivot', u'pandas-groupby']
# [u'python', u'pipe', u'subprocess']
# [u'python']
# FILENAME_004.html
# [u'python', u'shell', u'subprocess']
# [u'python', u'list', u'list-comprehension']
# [u'python', u'list', u'indexing']
# [u'python', u'design-patterns', u'class-design']
# [u'python', u'string', u'python-3.x']
# [u'python', u'recursion']
# [u'python', u'iterator', u'iteration']
# [u'python', u'immutability', u'mutable']
# [u'python', u'matplotlib', u'legend']
# [u'python', u'language-features', u'with-statement']
# [u'python', u'validation', u'tkinter', u'textbox']
# [u'python', u'hidden-features']
# [u'python', u'oop', u'inheritance', u'types']
# [u'python', u'executable']
# [u'python', u'file']
# [u'python', u'flask', u'flask-login']
# [u'python', u'encoding', u'text-files']
# [u'python', u'arrays', u'numpy', u'unique']
# [u'python', u'tkinter']
# [u'python', u'multithreading', u'multiprocessing']
# [u'python', u'string', u'substring', u'contains']
# [u'python', u'dictionary', u'list-comprehension', u'language-features', u'dict-comprehension']
# [u'python', u'datetime', u'iso8601', u'datetime-parsing', u'rfc3339']
# [u'python', u'list']
# [u'python', u'oop', u'methods', u'python-decorators']
# [u'python', u'properties', u'decorator', u'python-decorators', u'python-internals']
# [u'python', u'short-circuiting']
# [u'python', u'python-import']
# [u'python', u'list-comprehension', u'generator']
# [u'python', u'flask']
# [u'python', u'xml', u'xml-parsing', u'elementtree']
# [u'python', u'python-import']
# [u'python', u'class', u'object', u'inheritance']
# [u'python', u'file-io', u'generator']
# [u'python', u'python-3.x', u'unicode', u'python-2.x', u'diacritics']
# [u'python', u'string', u'replace']
# [u'python', u'datetime', u'timezone']
# [u'python', u'mongodb', u'pandas', u'hdf5', u'large-data']
# [u'python', u'python-3.x', u'python-import']
# [u'python', u'generator']
# [u'python', u'python-3.x', u'scope', u'list-comprehension', u'python-internals']
# [u'python', u'file-read']
# [u'python', u'web-scraping', u'urlopen']
# [u'python', u'break', u'control-flow']
# [u'python', u'text-files', u'line-count']
# [u'python', u'memoization']
# [u'python', u'dictionary']
# [u'python', u'selenium', u'firefox', u'selenium-firefoxdriver', u'geckodriver']
# [u'python', u'math', u'syntax', u'operators']
# [u'python', u'subprocess']
# FILENAME_005.html
# [u'python', u'function', u'lambda', u'closures']
# [u'c++', u'python', u'c']
# [u'python', u'oop']
# [u'python', u'object', u'iterator']
# [u'python', u'timer']
# [u'python']
# [u'python', u'python-2.7', u'locale', u'ipython', u'ipython-notebook']
# [u'python', u'io']
# [u'python', u'multithreading', u'timeout', u'subprocess']
# [u'python', u'pip']
# [u'python', u'list']
# [u'python', u'file', u'copy', u'filesystems', u'copyfile']
# [u'python', u'list', u'random']
# [u'python']
# [u'python', u'file-io']
# [u'python']
# [u'python', u'string', u'format', u'string-formatting', u'curly-braces']
# [u'python', u'slots']
# [u'python', u'matrix', u'syntax-error']
# [u'python', u'data-structures', u'dictionary', u'mapping', u'autovivification']
# [u'python', u'multithreading', u'multiprocessing', u'pickle', u'pool']
# [u'python', u'dictionary']
# [u'python']
# [u'python', u'syntax', u'parameter-passing', u'identifier', u'kwargs']
# [u'python', u'importerror', u'python-import']
# [u'python', u'python-import']
# [u'python', u'regex', u'string', u'numbers']
# [u'python', u'tkinter']
# [u'python', u'exception', u'exception-handling', u'error-handling', u'try-catch']
# [u'python', u'text', u'replace']
# [u'python', u'timeout', u'keyboard-input']
# [u'python', u'string', u'dictionary']
# [u'python', u'packaging', u'py2exe']
# [u'python', u'python-3.x', u'dictionary', u'python-internals', u'python-3.6']
# [u'python', u'set']
# [u'python', u'python-2.7', u'subprocess', u'espeak']
# [u'javascript', u'python', u'functional-programming', u'transpose']
# [u'python', u'syntax']
# [u'python']
# [u'python', u'properties', u'getter-setter']
# [u'python', u'python-2.7', u'relative', u'import']
# [u'python', u'file']
# [u'python', u'string', u'comparison', u'equality']
# [u'python', u'pandas', u'dataframe']
# [u'python', u'list', u'matrix', u'unzip', u'transpose']
# [u'python', u'windows', u'python-2.7', u'path']
# [u'python', u'json', u'flask']
# [u'python', u'python-3.x']
# [u'python', u'floating-point']
# [u'python', u'file-io']

# %% [markdown]
# OK, so we have figured out how to get at the data with Beautiful Soup above.  Let's wrap all of that logic into a function that accepts an HTML as an argument and returns a sequence of question objects -- each object will contain all of the attributes.  Each of these will become a row in a Pandas DataFrame.

# %%
def extract_question_objects(relative_html_path):
    """
        :relative_html_path: file to read and parse for stack overflow questions
    """
    questions = []
    f = open(relative_html_path, 'r')
    
    soup = BeautifulSoup(f.read(), 'html.parser')
    question_divs = soup.find_all("div", class_="question-summary")
        
    for question in question_divs:
            qid = question['id'].split("-")[2]
            text = question.find('a', class_="question-hyperlink").text
            tags = [tag.text for tag in question.find_all('a', class_="post-tag")]
            views = int(question.find('div', class_="views")['title'].split(" ")[0].replace(",", ""))
            
            date = question.find('span', class_='relativetime')
            
            date_asked = date['title'] if date else None
            
            questions.append([qid, views, text, tags])
    
    f.close()
    
    return questions

# %%
dataset = []

for i in page_range:
    filename = "FILENAME_00{}.html".format(i)
    
    qs = extract_question_objects(filename)
    
    for q in qs:
        dataset.append(q)


# print(dataset)

# %%
print(len(dataset))
# Out:
# 250

# %% [markdown]
# OK, this raw data looks pretty clean.  It's time to explore.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd

import numpy as np

# dataset2 = {}

# # munge dict of lists into pd dataframe-acceptable format
# for q in dataset:
#     dataset2[]

df = pd.DataFrame(columns=['views', 'text', 'tags'], )

for data in dataset:
    qid, views, text, tags = data
    df.loc[qid] = [views, text, tuple(np.array(tags))]
# Out:
# /Users/Shared/anaconda3/envs/pytn/lib/python2.7/site-packages/pandas/core/nanops.py:39: UserWarning: The installed version of bottleneck 0.8.0 is not supported in pandas and will be not be used
# The minimum supported version is 1.0.0
#
#   ver=ver, min_ver=_MIN_BOTTLENECK_VERSION), UserWarning)

# %%
df
# Out:
#             views                                               text  \
# 1132941    103329  “Least Astonishment” and the Mutable Default A...
# 15112125    86361  How do I test multiple variables against a value?
# 509211     992325              Understanding Python's slice notation
# 23294658   203161  Asking the user for input until they give a va...
# 240178      15132  List of lists changes reflected across sublist...
# 2612802    856436                       How to clone or copy a list?
# 1373164     74882    How do I create a variable number of variables?
# 312443     534924  How do you split a list into evenly sized chunks?
# 986006     857645             How do I pass a variable by reference?
# 1207406    281090           Remove items from a list while iterating
# 952914     946569  Making a flat list out of list of lists in Python
# 20109391     5248      How to make good reproducible pandas examples
# 20449427   405353                 How can I read inputs as integers?
# 231767    1558593                  What does the “yield” keyword do?
# 291978     193185            Short Description of the Scoping Rules?
# 36901      341758  What does ** (double star/asterisk) and * (sta...
# 89228     2276430              Calling an external command in Python
# 419163    1467600           What does if __name__ == “__main__”: do?
# 423379    2387267  Using global variables in a function other tha...
# 613183    1566623               How do I sort a dictionary by value?
# 2158395     82918               Flatten (an irregular) list of lists
# 100003     556160                    What are metaclasses in Python?
# 4750806   2086144                   How do I install pip on Windows?
# 306313      43376   “is” operator behaves unexpectedly with integers
# 826948     172252    Syntax error on print with Python 3 [duplicate]
# 15479928    10065  Why is the order in dictionaries and sets arbi...
# 394809    1172039   Does Python have a ternary conditional operator?
# 1680528     14449  How to avoid having class data shared among in...
# 739654     412022        How to make a chain of function decorators?
# 323972     458169       Is there any way to kill a Thread in Python?
# ...           ...                                                ...
# 1816958     87080  Can't pickle <type 'instancemethod'> when usin...
# 526125      39878  Why is python ordering my dictionary like so? ...
# 5997027     16743  Python rounding error with float numbers [dupl...
# 2921847    104001      What does the Star operator mean? [duplicate]
# 4383571    475533              Importing files from different folder
# 710551      74122            'import module' or 'from module import'
# 4289331    415922              Python: Extract numbers from a string
# 17466561    64574        Best way to structure a tkinter application
# 21553327    79780  Why is “except: pass” a bad programming practice?
# 6116978    172203    How to replace multiple substrings of a string?
# 1335507     44513              Keyboard input with timeout in Python
# 988228     393796  Convert a String representation of a Dictionar...
# 112698     121634           py2exe - generate single executable file
# 39980323    19515           Are dictionaries ordered in Python 3.6+?
# 1653970    157774                   Does Python have an ordered set?
# 11269575   125552     How to hide output of subprocess in Python 2.7
# 4856717     41593     Javascript equivalent of Python's zip function
# 2464959     98294            What's the u prefix in a Python string?
# 5434891     29077   Iterate a list as pair (current, next) in Python
# 6618002    336777        Python @property versus getters and setters
# 14132789    57213            Relative imports for the billionth time
# 237079     458435  How to get file creation & modification date/t...
# 2988017    776791  String comparison in Python: is vs. == [duplic...
# 12065885   154526  Filter dataframe rows if value in column is in...
# 19339       87873         Transpose/Unzip Function (inverse of zip)?
# 6318156    388099                    Adding Python Path on Windows 7
# 13081532   192113               Return JSON response from Flask view
# 25445439   486341  What does “SyntaxError: Missing parentheses in...
# 5595425     93452  What is the best way to compare floats for alm...
# 3964681    960902  Find all files in a directory with extension ....
#
#                                                        tags
# 1132941       (python, language-design, least-astonishment)
# 15112125  (python, if-statement, comparison, match, bool...
# 509211                                (python, list, slice)
# 23294658  (python, validation, loops, python-3.x, user-i...
# 240178                (python, list, nested-lists, mutable)
# 2612802                         (python, list, copy, clone)
# 1373164                        (python, variable-variables)
# 312443                        (python, list, split, chunks)
# 986006    (python, reference, parameter-passing, pass-by...
# 1207406                                 (python, iteration)
# 952914      (python, list, multidimensional-array, flatten)
# 20109391                                   (python, pandas)
# 20449427              (python, python-2.7, python-3.x, int)
# 231767      (python, iterator, generator, yield, coroutine)
# 291978                   (python, scope, dynamic-languages)
# 36901     (python, syntax, parameter-passing, identifier...
# 89228        (python, shell, command, subprocess, external)
# 419163           (python, module, namespaces, main, idioms)
# 423379                    (python, global-variables, scope)
# 613183                        (python, sorting, dictionary)
# 2158395               (python, list, optimization, flatten)
# 100003           (python, oop, metaclass, python-datamodel)
# 4750806   (python, windows, installation, pip, easy-inst...
# 306313       (python, int, comparison, operators, identity)
# 826948                                 (python, python-3.x)
# 15479928  (python, dictionary, order, set, python-intern...
# 394809    (python, operators, ternary-operator, conditio...
# 1680528                                     (python, class)
# 739654               (python, decorator, python-decorators)
# 323972            (python, multithreading, kill, terminate)
# ...                                                     ...
# 1816958   (python, multithreading, multiprocessing, pick...
# 526125                                 (python, dictionary)
# 5997027                                           (python,)
# 2921847   (python, syntax, parameter-passing, identifier...
# 4383571                (python, importerror, python-import)
# 710551                              (python, python-import)
# 4289331                    (python, regex, string, numbers)
# 17466561                                  (python, tkinter)
# 21553327  (python, exception, exception-handling, error-...
# 6116978                             (python, text, replace)
# 1335507                   (python, timeout, keyboard-input)
# 988228                         (python, string, dictionary)
# 112698                          (python, packaging, py2exe)
# 39980323  (python, python-3.x, dictionary, python-intern...
# 1653970                                       (python, set)
# 11269575           (python, python-2.7, subprocess, espeak)
# 4856717   (javascript, python, functional-programming, t...
# 2464959                                    (python, syntax)
# 5434891                                           (python,)
# 6618002                 (python, properties, getter-setter)
# 14132789             (python, python-2.7, relative, import)
# 237079                                       (python, file)
# 2988017              (python, string, comparison, equality)
# 12065885                        (python, pandas, dataframe)
# 19339              (python, list, matrix, unzip, transpose)
# 6318156                 (python, windows, python-2.7, path)
# 13081532                              (python, json, flask)
# 25445439                               (python, python-3.x)
# 5595425                            (python, floating-point)
# 3964681                                   (python, file-io)
#
# [250 rows x 3 columns]

# %% [markdown]
# Let's run some preliminary summary statistics.

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>250 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>7.9 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>32.3 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>tags</code> has a high cardinality: 224 distinct values  <span class="label label-warning">Warning</span></l> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4">index<br/>
#             <small>Categorical, Unique</small>
#         </p>
#     </div><div class="col-md-3 collapse in" id="minivalues-8139544016919160671"><table border="1" class="dataframe example_values">
#   <thead>
#     <tr style="text-align: right;">
#       <th>First 3 values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3906137</td>
#     </tr>
#     <tr>
#       <td>10434599</td>
#     </tr>
#     <tr>
#       <td>890128</td>
#     </tr>
#   </tbody>
# </table></div>
# <div class="col-md-6 collapse in" id="minivalues-8139544016919160671"><table border="1" class="dataframe example_values">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Last 3 values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>67631</td>
#     </tr>
#     <tr>
#       <td>1101750</td>
#     </tr>
#     <tr>
#       <td>2386714</td>
#     </tr>
#   </tbody>
# </table></div>
# <div class="col-md-12 text-right">
#     <a role="button" data-toggle="collapse" data-target="#values-8139544016919160671,#minivalues-8139544016919160671" aria-expanded="false"
#        aria-controls="collapseExample">
#         Toggle details
#     </a>
# </div>
# <div class="col-md-12 collapse" id="values-8139544016919160671">
#     <p class="h4">First 10 values</p>
#
# <table class="freq tab

# %%
dir(profile)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_repr_html_',
#  'description_set',
#  'file',
#  'get_description',
#  'get_rejected_variables',
#  'html',
#  'to_file']

# %%
# Out:
# u'<meta charset="UTF-8">\n\n<style>\n\n        .variablerow {\n            border: 1px solid #e1e1e8;\n            border-top: hidden;\n            padding-top: 2em;\n            padding-bottom: 2em;\n            padding-left: 1em;\n            padding-right: 1em;\n        }\n\n        .headerrow {\n            border: 1px solid #e1e1e8;\n            background-color: #f5f5f5;\n            padding: 2em;\n        }\n        .namecol {\n            margin-top: -1em;\n            overflow-x: auto;\n        }\n\n        .dl-horizontal dt {\n            text-align: left;\n            padding-right: 1em;\n            white-space: normal;\n        }\n\n        .dl-horizontal dd {\n            margin-left: 0;\n        }\n\n        .ignore {\n            opacity: 0.4;\n        }\n\n        .container.pandas-profiling {\n            max-width:975px;\n        }\n\n        .col-md-12 {\n            padding-left: 2em;\n        }\n\n        .indent {\n            margin-left: 1em;\n        }\n\n        /* Table example_values */\n            table.example_values {\n                border: 0;\n            }\n\n            .example_values th {\n                border: 0;\n                padding: 0 ;\n                color: #555;\n                font-weight: 600;\n            }\n\n            .example_values tr, .example_values td{\n                border: 0;\n                padding: 0;\n                color: #555;\n            }\n\n        /* STATS */\n            table.stats {\n                border: 0;\n            }\n\n            .stats th {\n                border: 0;\n                padding: 0 2em 0 0;\n                color: #555;\n                font-weight: 600;\n            }\n\n            .stats tr {\n                border: 0;\n            }\n\n            .stats tr:hover{\n                text-decoration: underline;\n            }\n\n            .stats td{\n                color: #555;\n                padding: 1px;\n                border: 0;\n            }\n\n\n        /* Sample table */\n            table.sample {\n                border: 0;\n                margin-bottom: 2em;\n                margin-left:1em;\n            }\n            .sample tr {\n                border:0;\n            }\n            .sample td, .sample th{\n                padding: 0.5em;\n                white-space: nowrap;\n                border: none;\n\n            }\n\n            .sample thead {\n                border-top: 0;\n                border-bottom: 2px solid #ddd;\n            }\n\n            .sample td {\n                width:100%;\n            }\n\n\n        /* There is no good solution available to make the divs equal height and then center ... */\n            .histogram {\n                margin-top: 3em;\n            }\n        /* Freq table */\n\n            table.freq {\n                margin-bottom: 2em;\n                border: 0;\n            }\n            table.freq th, table.freq tr, table.freq td {\n                border: 0;\n                padding: 0;\n            }\n\n            .freq thead {\n                font-weight: 600;\n                white-space: nowrap;\n                overflow: hidden;\n                text-overflow: ellipsis;\n\n            }\n\n            td.fillremaining{\n                width:auto;\n                max-width: none;\n            }\n\n            td.number, th.number {\n                text-align:right ;\n            }\n\n        /* Freq mini */\n            .freq.mini td{\n                width: 50%;\n                padding: 1px;\n                font-size: 12px;\n\n            }\n            table.freq.mini {\n                 width:100%;\n            }\n            .freq.mini th {\n                overflow: hidden;\n                text-overflow: ellipsis;\n                white-space: nowrap;\n                max-width: 5em;\n                font-weight: 400;\n                text-align:right;\n                padding-right: 0.5em;\n            }\n\n            .missin ...
