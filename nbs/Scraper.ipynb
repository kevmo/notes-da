# %% [markdown]
# # Scraping Raw Data From Stack Overflow

# %%
# get inline, interactivate plots
# %matplotlib notebook

# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Identify the data

# %% [markdown]
# Data Source: All the questions on Stack Overflow that have the "Python" tag on them.
#
# --> Question: Where exactly does all of this data live -- what is the URL structure we can use to
# acquire all of this user data.  Go look at Stack Overflow.
#
# --> Task: Work the URL into a formattable string you can feed into a srcaper.

# %%
SO_URL_format = "https://stackoverflow.com/questions/tagged/python?page={0}&sort=frequent&pagesize=50"

# %% [markdown]
# ## Acquire the raw data

# %%
number_of_pages_to_gather = 50

# create sequence of page
page_range = range(1, number_of_pages_to_gather + 1)

# %% [markdown]
# So you may have noticed when we were formatting the URL that there are actually 1000s of pages of Python questions,
# but here we're only collecting 50. This is intentional and temporary. Eventually we should collect the entire corpus of data, but right now we are trying to prototype a workflow.  So we are going to temporarily "downsample" to work faster.  In fact, 50 is pretty high.  Let's kick it down to 5 files.  That way, we are still coding with the for conditions where we need to take multiple files (as opposed to just one), but not introducing lots of computing time.

# %%
page_range = range(1, 6)

# %%
import requests 

for i in page_range:
    print("you don't have wifi right now so don't erase ur data")
#     so_response = requests.get(SO_URL_format.format(i))
#     if so_response.status_code == 200:
#         html_file = open('FILENAME_00{0}.html'.format(i),'w')
#         html_file.write(so_response.text)
#         html_file.close()
#     else:
#         raise Error

# TODO: make this code block more functional
# Out:
# you don't have wifi right now so don't erase ur data
# you don't have wifi right now so don't erase ur data
# you don't have wifi right now so don't erase ur data
# you don't have wifi right now so don't erase ur data
# you don't have wifi right now so don't erase ur data

# %% [markdown]
# ## Mash Until No Good -- Data Munging/Cleaning/Wrangling

# %% [markdown]
# > Bad programmers spend their time thinking about the code.  Good programmers
# > spend their time thinking about data structures.
#
# > Linus Torvalds

# %% [markdown]
# > I be in the kitchen whipping
# >
# > trying to cook the sauce.
# >
# >   Yo Gotti

# %% [markdown]
# We are not going to begin whipping this data into shape for various levels of analysis - it's hard to do
# analysis on a bunch of data locked up in an HTML structure though.

# %% [markdown]
# #### Extracting the maximum number of dimensions from the data

# %% [markdown]
# Look at the stack overflow page and think about what our granular data points are.  For the pages
# we have decided to
#
# < INSERT PICTURE OF SO PAGE HERE >
#
# The granular logical data point is a question.  So what are the dimensions/attributes of a question object?
# - question text
# - vote score
# - views
# - details
# - author
# - question details
#
# Beautiful soup parses the HTML into a Python tree structure (DOM).  You can then use a variety of BS4 methods to extract specific HTML elements based on HTML attritbute.  Since classes and IDs are HTML attributes, you can use CSS selectors to extract information.

# %%
# insert quick BS4 demo before doing the real code in the next block

# %% [markdown]
# OK, let's actually get the question text, vote score, views, etc. out of the data.

# %%
from bs4 import BeautifulSoup

# %%
# for i in page_range:
#     file_name = 'FILENAME_00{0}.html'.format(i)
#     print(file_name)
    
#     with open(file_name,'r') as f:
#         soup = BeautifulSoup(f.read(), 'html.parser')
        
#         # for each file, get all of the question objects
#         questions = soup.find_all("div", class_="question-summary")
        
#         for question in questions:
#             text = question.find('a', class_="question-hyperlink").text
#             tags = [tag.text for tag in question.find_all('a', class_="post-tag")]
#             views = int(question.find('div', class_="views")['title'].split(" ")[0].replace(",", ""))
#             date_asked = 
#             author
#             print(supernova, text)
#             print(tags)

# %% [markdown]
# OK, so we have figured out how to get at the data with Beautiful Soup above.  Let's wrap all of that logic into a function that accepts an HTML as an argument and returns a sequence of question objects -- each object will contain all of the attributes.  Each of these will become a row in a Pandas DataFrame.

# %%
def extract_question_objects(relative_html_path):
    """
        :relative_html_path: What it sounds like
    """
    questions = []
    f = open(relative_html_path, 'r')
    
    soup = BeautifulSoup(f.read(), 'html.parser')
    question_divs = soup.find_all("div", class_="question-summary")
        
    for question in question_divs:
            id = question['id'].split("-")[2]
            text = question.find('a', class_="question-hyperlink").text
            tags = [tag.text for tag in question.find_all('a', class_="post-tag")]
            views = int(question.find('div', class_="views")['title'].split(" ")[0].replace(",", ""))
    
            
            questions.append({id: [text, tags, views]})
    
    f.close()
    
    return questions

# %%
dataset = []

for i in page_range:
    filename = "FILENAME_00{}.html".format(i)
    
    qs = extract_question_objects(filename)
    
    for q in qs:
        dataset.append(q)


# print(dataset)

# %%
for i in dataset:
    print i
# Out:
# {u'1132941': [u'\u201cLeast Astonishment\u201d and the Mutable Default Argument', [u'python', u'language-design', u'least-astonishment'], 103225]}
# {u'15112125': [u'How do I test multiple variables against a value?', [u'python', u'if-statement', u'comparison', u'match', u'boolean-logic'], 86153]}
# {u'509211': [u"Understanding Python's slice notation", [u'python', u'list', u'slice'], 990799]}
# {u'23294658': [u'Asking the user for input until they give a valid response', [u'python', u'validation', u'loops', u'python-3.x', u'user-input'], 202609]}
# {u'240178': [u'List of lists changes reflected across sublists unexpectedly', [u'python', u'list', u'nested-lists', u'mutable'], 15103]}
# {u'2612802': [u'How to clone or copy a list?', [u'python', u'list', u'copy', u'clone'], 854693]}
# {u'1373164': [u'How do I create a variable number of variables?', [u'python', u'variable-variables'], 74766]}
# {u'312443': [u'How do you split a list into evenly sized chunks?', [u'python', u'list', u'split', u'chunks'], 534321]}
# {u'986006': [u'How do I pass a variable by reference?', [u'python', u'reference', u'parameter-passing', u'pass-by-reference'], 856440]}
# {u'1207406': [u'Remove items from a list while iterating', [u'python', u'iteration'], 280736]}
# {u'952914': [u'Making a flat list out of list of lists in Python', [u'python', u'list', u'multidimensional-array', u'flatten'], 944896]}
# {u'20109391': [u'How to make good reproducible pandas examples', [u'python', u'pandas'], 5212]}
# {u'20449427': [u'How can I read inputs as integers?', [u'python', u'python-2.7', u'python-3.x', u'int'], 403984]}
# {u'231767': [u'What does the \u201cyield\u201d keyword do?', [u'python', u'iterator', u'generator', u'yield', u'coroutine'], 1556573]}
# {u'291978': [u'Short Description of the Scoping Rules?', [u'python', u'scope', u'dynamic-languages'], 192888]}
# {u'36901': [u'What does ** (double star/asterisk) and * (star/asterisk) do for parameters?', [u'python', u'syntax', u'parameter-passing', u'identifier', u'kwargs'], 341013]}
# {u'89228': [u'Calling an external command in Python', [u'python', u'shell', u'command', u'subprocess', u'external'], 2273799]}
# {u'419163': [u'What does if __name__ == \u201c__main__\u201d: do?', [u'python', u'module', u'namespaces', u'main', u'idioms'], 1464439]}
# {u'423379': [u'Using global variables in a function other than the one that created them', [u'python', u'global-variables', u'scope'], 2384420]}
# {u'613183': [u'How do I sort a dictionary by value?', [u'python', u'sorting', u'dictionary'], 1564510]}
# {u'2158395': [u'Flatten (an irregular) list of lists', [u'python', u'list', u'optimization', u'flatten'], 82849]}
# {u'100003': [u'What are metaclasses in Python?', [u'python', u'oop', u'metaclass', u'python-datamodel'], 555597]}
# {u'4750806': [u'How do I install pip on Windows?', [u'python', u'windows', u'installation', u'pip', u'easy-install'], 2083065]}
# {u'306313': [u'\u201cis\u201d operator behaves unexpectedly with integers', [u'python', u'int', u'comparison', u'operators', u'identity'], 43324]}
# {u'826948': [u'Syntax error on print with Python 3 [duplicate]', [u'python', u'python-3.x'], 172081]}
# {u'394809': [u'Does Python have a ternary conditional operator?', [u'python', u'operators', u'ternary-operator', u'conditional-operator', u'python-2.5'], 1169977]}
# {u'15479928': [u'Why is the order in dictionaries and sets arbitrary?', [u'python', u'dictionary', u'order', u'set', u'python-internals'], 10045]}
# {u'1680528': [u'How to avoid having class data shared among instances?', [u'python', u'class'], 14423]}
# {u'739654': [u'How to make a chain of function decorators?', [u'python', u'decorator', u'python-decorators'], 411803]}
# {u'323972': [u'Is there any way to kill a Thread in Python?', [u'python', u'multithreading', u'kill', u'terminate'], 457596]}
# {u'1436703': [u'Difference between __str__ and __repr__ in Python', [u'python', u'repr'], 410414]}
# {u'5767228': [u'Why is Button parameter \u201ccommand\u201d executed when declared?', [u'python', u'tkinter'], 9869]}
# {u'20002503': [u'Why does `a == b or c or d` always evaluate to True? [duplicate]', [u'python', u'boolean', u'boolean-expression'], 9051]}
# {u'1832940': [u"Why is using 'eval' a bad practice?", [u'python', u'eval'], 21279]}
# {u'2709821': [u'What is the purpose of self?', [u'python', u'class', u'oop', u'self'], 584467]}
# {u'1301346': [u'What is the meaning of a single- and a double-underscore before an object name?', [u'python', u'naming-conventions', u'private', u'underscores', u'double-underscore'], 246147]}
# {u'480214': [u'How do you remove duplicates from a list in whilst preserving order?', [u'python', u'list', u'duplicates', u'unique'], 426479]}
# {u'2817869': [u'error: Unable to find vcvarsall.bat', [u'python', u'windows', u'pip', u'setup.py', u'failed-installation'], 765407]}
# {u'406121': [u'Flattening a shallow list in Python [duplicate]', [u'python', u'list-comprehension'], 144779]}
# {u'1504717': [u"Why does comparing strings in Python using either '==' or 'is' sometimes produce a different result?", [u'python', u'string', u'comparison'], 1075940]}
# {u'68645': [u'Static class variables in Python', [u'python', u'class', u'methods', u'static', u'class-variables'], 823393]}
# {u'3701646': [u'How to add to the pythonpath in windows 7?', [u'python', u'windows', u'environment-variables', u'pythonpath'], 714469]}
# {u'21122540': [u"input() error - NameError: name '\u2026' is not defined", [u'python', u'python-2.7', u'python-3.x', u'input', u'nameerror'], 350329]}
# {u'533905': [u'Get the cartesian product of a series of lists?', [u'python', u'list'], 100500]}
# {u'466345': [u'Converting string into datetime', [u'python', u'datetime'], 1474956]}
# {u'1267869': [u'How can I force division to be floating point? Division keeps rounding down to 0', [u'python', u'floating-point', u'integer', u'division', u'python-2.x'], 480542]}
# {u'434287': [u'What is the most \u201cpythonic\u201d way to iterate over a list in chunks?', [u'python', u'list', u'loops', u'optimization', u'chunks'], 74384]}
# {u'1663807': [u'How to iterate through two lists in parallel?', [u'python', u'iterator'], 317978]}
# {u'38987': [u'How to merge two dictionaries in a single expression?', [u'python', u'python-3.x', u'dictionary', u'mapping', u'idioms'], 991718]}
# {u'582336': [u'How can you profile a script?', [u'python', u'performance', u'profiling', u'time-complexity'], 324946]}
# {u'54867': [u'What is the difference between old style and new style classes in Python?', [u'python', u'class', u'oop', u'types', u'new-style-class'], 172136]}
# {u'493386': [u'How to print without newline or space?', [u'python', u'newline'], 1156917]}
# {u'4836710': [u'Does Python have a built in function for string natural sort?', [u'python', u'sorting', u'python-3.x'], 46521]}
# {u'3394835': [u'*args and **kwargs? [duplicate]', [u'python', u'args', u'kwargs'], 688084]}
# {u'2068372': [u'Fastest way to list all primes below N', [u'python', u'math', u'optimization', u'primes'], 143459]}
# {u'67631': [u'How to import a module given the full path?', [u'python', u'configuration', u'python-import', u'python-module'], 491330]}
# {u'36250353': [u'Importing installed package from script raises \u201cAttributeError: module has no attribute\u201d or \u201cImportError: cannot import name\u201d', [u'python', u'exception', u'python-module', u'shadowing'], 3397]}
# {u'3270680': [u'How does Python compare string and int?', [u'python', u'types', u'comparison', u'python-2.x'], 65243]}
# {u'132988': [u'Is there a difference between `==` and `is` in Python?', [u'python', u'reference', u'semantics'], 202677]}
# {u'107705': [u'Disable output buffering', [u'python', u'stdout', u'buffered'], 182429]}
# {u'12423614': [u'Local variables in Python nested functions', [u'python', u'scope', u'closures', u'nested-function'], 6931]}
# {u'375427': [u'Non-blocking read on a subprocess.PIPE in python', [u'python', u'io', u'subprocess', u'nonblocking'], 164905]}
# {u'576169': [u'Understanding Python super() with __init__() methods [duplicate]', [u'python', u'oop', u'inheritance', u'super'], 1169906]}
# {u'104420': [u'How to generate all permutations of a list in Python', [u'python', u'algorithm', u'permutation', u'combinatorics', u'python-2.5'], 383820]}
# {u'5036700': [u'How can you dynamically create variables via a while loop? [duplicate]', [u'python', u'variables'], 152010]}
# {u'81584': [u'What IDE to use for Python? [closed]', [u'python', u'ide', u'editor'], 1533675]}
# {u'1247486': [u'Python List Comprehension Vs. Map', [u'python', u'list-comprehension', u'map-function'], 126216]}
# {u'370357': [u'Python variable scope error', [u'python', u'variables', u'scope'], 49657]}
# {u'4706499': [u'How do you append to a file?', [u'python', u'file', u'append'], 1066280]}
# {u'2081640': [u'What exactly do \u201cu\u201d and \u201cr\u201d string flags do, and what are raw string literals?', [u'python', u'unicode', u'rawstring'], 220631]}
# {u'1894269': [u'Convert string representation of list to list in Python', [u'python', u'string'], 134705]}
# {u'510357': [u'Python read a single character from the user', [u'python', u'input'], 189221]}
# {u'9001509': [u'How can I sort a dictionary by key?', [u'python', u'sorting', u'dictionary'], 751481]}
# {u'3061': [u'Calling a function of a module by using its name (a string)', [u'python'], 417813]}
# {u'1867861': [u'Python dictionary, how to keep keys/values in same order as declared?', [u'python', u'dictionary', u'order'], 172963]}
# {u'4915361': [u"What's the difference between raw_input() and input() in python3.x?", [u'python', u'python-3.x'], 222669]}
# {u'5419': [u'Python, Unicode, and the Windows console', [u'python', u'unicode'], 62853]}
# {u'2600191': [u'How to count the occurrences of a list item?', [u'python', u'list', u'count'], 839285]}
# {u'1912434': [u'How do I parse XML in Python?', [u'python', u'xml'], 803490]}
# {u'20646822': [u'How to serve static files in Flask', [u'python', u'flask', u'static-files'], 282786]}
# {u'1101750': [u'Tkinter: AttributeError: NoneType object has no attribute get', [u'python', u'user-interface', u'tkinter'], 46832]}
# {u'9264763': [u'UnboundLocalError in Python [duplicate]', [u'python', u'global-variables', u'scope'], 91590]}
# {u'448271': [u'What is __init__.py for?', [u'python', u'module'], 498690]}
# {u'180986': [u'What is the difference between re.search and re.match?', [u'python', u'regex', u'search', u'match'], 178346]}
# {u'2295290': [u'What do (lambda) function closures capture?', [u'python', u'lambda', u'closures'], 26870]}
# {u'4789837': [u'How to terminate a python subprocess launched with shell=True', [u'python', u'linux', u'subprocess', u'kill-process'], 164431]}
# {u'5082452': [u'Python string formatting: % vs. .format', [u'python', u'performance', u'logging', u'string-formatting'], 837778]}
# {u'72852': [u'How to do relative imports in Python?', [u'python', u'python-import', u'python-module'], 245641]}
# {u'9060653': [u'List comprehension without [ ] in Python', [u'python', u'list-comprehension'], 8630]}
# {u'3207219': [u'How do I list all files of a directory?', [u'python', u'directory'], 2001859]}
# {u'60208': [u'Replacements for switch statement in Python?', [u'python'], 1016268]}
# {u'36932': [u"How can I represent an 'Enum' in Python?", [u'python', u'python-3.x', u'enums'], 593522]}
# {u'3294889': [u"Iterating over dictionaries using 'for' loops", [u'python', u'python-2.7', u'dictionary'], 2395986]}
# {u'4295799': [u'How to improve performance of this code?', [u'python', u'performance', u'optimization', u'time-complexity'], 11494]}
# {u'9942594': [u"UnicodeEncodeError: 'ascii' codec can't encode character u'\\xa0' in position 20: ordinal not in range(128)", [u'python', u'unicode', u'beautifulsoup', u'python-2.x', u'python-unicode'], 908701]}
# {u'2835559': [u'Parsing values from a JSON file?', [u'python', u'json', u'parsing'], 1622892]}
# {u'5893163': [u'What is the purpose of the single underscore \u201c_\u201d variable in Python?', [u'python', u'variables', u'naming-conventions', u'underscores', u'metasyntactic-variable'], 152259]}
# {u'2715847': [u'Python: read streaming input from subprocess.communicate()', [u'python', u'subprocess'], 56378]}
# {u'1534210': [u'Use different Python version with virtualenv', [u'python', u'virtualenv', u'virtualenvwrapper'], 353486]}
# {u'931092': [u'Reverse a string in Python', [u'python', u'string'], 823409]}
# {u'265960': [u'Best way to strip punctuation from a string in Python', [u'python', u'string', u'punctuation'], 355417]}
# {u'7961363': [u'Removing duplicates in lists', [u'python', u'algorithm', u'list', u'duplicates', u'intersection'], 751273]}
# {u'17299581': [u'Loop \u201cForgets\u201d to Remove Some Items [duplicate]', [u'python', u'string', u'list'], 5886]}
# {u'230751': [u'How to flush output of Python print?', [u'python', u'printing', u'flush'], 474061]}
# {u'4675728': [u'Redirect stdout to a file in Python?', [u'python', u'stdout'], 286623]}
# {u'8777753': [u'Converting datetime.date to UTC timestamp in Python', [u'python', u'datetime', u'utc'], 302747]}
# {u'2958684': [u'Python division', [u'python', u'math', u'python-2.x'], 292423]}
# {u'354038': [u'How do I check if a string is a number (float)?', [u'python', u'casting', u'floating-point', u'type-conversion'], 867216]}
# {u'20625582': [u'How to deal with SettingWithCopyWarning in Pandas?', [u'python', u'pandas', u'dataframe', u'chained-assignment'], 200115]}
# {u'19158339': [u'Why are global variables evil?', [u'python', u'global-variables', u'side-effects'], 26232]}
# {u'2846653': [u'How to use threading in Python?', [u'python', u'multithreading'], 609853]}
# {u'287871': [u'Print in terminal with colors?', [u'python', u'unicode', u'terminal', u'ansi-colors'], 664462]}
# {u'72899': [u'How do I sort a list of dictionaries by values of the dictionary in Python?', [u'python', u'list', u'sorting', u'dictionary', u'data-structures'], 450887]}
# {u'261638': [u'How do I protect Python code?', [u'python', u'licensing', u'obfuscation', u'copy-protection'], 191939]}
# {u'455612': [u'Limiting floats to two decimal points', [u'python', u'floating-point', u'rounding', u'precision'], 1661507]}
# {u'301134': [u'Dynamic module import in Python', [u'python', u'python-import'], 199774]}
# {u'1682567': [u'Why does list.append evaluate to false?', [u'python', u'arrays', u'immutability'], 5476]}
# {u'522563': [u"Accessing the index in Python 'for' loops", [u'python', u'loops', u'list'], 1118373]}
# {u'3277367': [u"How does Python's super() work with multiple inheritance?", [u'python', u'multiple-inheritance'], 187954]}
# {u'4693120': [u'Use of \u201cglobal\u201d keyword in Python', [u'python', u'global-variables'], 317761]}
# {u'207000': [u'Python: Difference between class and instance attributes', [u'python', u'attributes'], 50543]}
# {u'437589': [u'How do I unload (reload) a Python module?', [u'python', u'module', u'reload', u'python-import'], 404797]}
# {u'464864': [u'How to get all possible combinations of a list\u2019s elements?', [u'python', u'combinations'], 302863]}
# {u'2087370': [u'Decode HTML entities in Python string?', [u'python', u'html', u'html-entities'], 134943]}
# {u'2371436': [u'Evaluating a mathematical expression in a string', [u'python', u'math'], 71207]}
# {u'492519': [u'Timeout on a function call', [u'python', u'multithreading', u'timeout', u'python-multithreading'], 146008]}
# {u'2429511': [u'Why do people write #!/usr/bin/env python on the first line of a Python script?', [u'python', u'shell', u'shebang'], 471832]}
# {u'279237': [u'Import a module from a relative path', [u'python', u'relative-path', u'python-import'], 764699]}
# {u'972': [u'Adding a Method to an Existing Object Instance', [u'python', u'oop', u'methods', u'monkeypatching'], 150042]}
# {u'1059559': [u'Split Strings with Multiple Delimiters?', [u'python', u'string', u'split'], 402082]}
# {u'1769403': [u'Understanding kwargs in Python', [u'python', u'kwargs'], 419992]}
# {u'22676': [u'How do I download a file over HTTP using Python?', [u'python', u'http', u'urllib'], 708404]}
# {u'379906': [u'Parse String to Float or Int', [u'python', u'string', u'parsing', u'floating-point', u'integer'], 2642797]}
# {u'182197': [u'How do I watch a file for changes?', [u'python', u'file', u'pywin32', u'watch'], 174320]}
# {u'743806': [u'How to split a string into a list?', [u'python', u'list', u'split', u'text-segmentation'], 1222428]}
# {u'82831': [u'How do I check whether a file exists using Python?', [u'python', u'file', u'filesystems'], 2480608]}
# {u'209840': [u'Map two lists into a dictionary in Python', [u'python', u'dictionary'], 366162]}
# {u'1009860': [u'How to read/process command line arguments?', [u'python', u'command-line', u'command-line-arguments'], 438012]}
# {u'6269765': [u"What does the 'b' character do in front of a string literal?", [u'python', u'string', u'unicode', u'binary'], 213576]}
# {u'6822725': [u'Rolling or sliding window iterator?', [u'python', u'algorithm'], 42456]}
# {u'252703': [u'Difference between append vs. extend list methods in Python', [u'python', u'list', u'data-structures', u'append', u'extend'], 1904982]}
# {u'110259': [u'Which Python memory profiler is recommended? [closed]', [u'python', u'performance', u'memory-management', u'profiling'], 155151]}
# {u'1450393': [u'How do you read from stdin in Python?', [u'python', u'stdin'], 1050794]}
# {u'744373': [u'Circular (or cyclic) imports in Python', [u'python', u'circular-dependency', u'cyclic-reference'], 83171]}
# {u'7546050': [u'Switch between two frames in tkinter', [u'python', u'python-3.x', u'tkinter', u'frame'], 47388]}
# {u'626759': [u"What's the difference between lists and tuples?", [u'python', u'list', u'tuples'], 297201]}
# {u'47152691': [u'How to pivot a dataframe', [u'python', u'pandas', u'group-by', u'pivot', u'pandas-groupby'], 1492]}
# {u'295459': [u'How do I use subprocess.Popen to connect multiple processes by pipes?', [u'python', u'pipe', u'subprocess'], 39492]}
# {u'372885': [u'How do I connect to a MySQL Database in Python?', [u'python', u'mysql'], 868927]}
# {u'4760215': [u'Running shell command from Python and capturing the output', [u'python', u'shell', u'subprocess'], 573437]}
# {u'34835951': [u'What does \u201clist comprehension\u201d mean? How does it work and how can I use it?', [u'python', u'list', u'list-comprehension'], 1809]}
# {u'6260089': [u'strange result when removing item from a list [duplicate]', [u'python'], 3598]}
# {u'176918': [u'Finding the index of an item given a list containing it in Python', [u'python', u'list', u'indexing'], 2123159]}
# {u'674304': [u'Why is __init__() always called after __new__()?', [u'python', u'design-patterns', u'class-design'], 192674]}
# {u'606191': [u'Convert bytes to a string?', [u'python', u'string', u'python-3.x'], 889111]}
# {u'3323001': [u'What is the maximum recursion depth in Python, and how to increase it?', [u'python', u'recursion'], 198520]}
# {u'9884132': [u"What exactly are Python's iterator, iterable, and iteration protocols?", [u'python', u'iterator', u'iteration'], 164890]}
# {u'8056130': [u'Immutable vs Mutable types', [u'python', u'immutability', u'mutable'], 204362]}
# {u'4140437': [u'Interactively validating Entry widget content in tkinter', [u'python', u'validation', u'tkinter', u'textbox'], 32573]}
# {u'101268': [u'Hidden features of Python [closed]', [u'python', u'hidden-features'], 608113]}
# {u'1549801': [u'What are the differences between type() and isinstance()?', [u'python', u'oop', u'inheritance', u'types'], 495996]}
# {u'3012488': [u'What is the python \u201cwith\u201d statement designed for?', [u'python', u'language-features', u'with-statement'], 67354]}
# {u'39086': [u'Search and replace a line in a file in Python', [u'python', u'file'], 310345]}
# {u'21406057': [u"Flask view raises TypeError: 'bool' object is not callable", [u'python', u'flask', u'flask-login'], 2896]}
# {u'4700614': [u'How to put the legend out of the plot', [u'python', u'matplotlib', u'legend'], 370385]}
# {u'10434599': [u'How to get data received in Flask request', [u'python', u'flask'], 260832]}
# {u'436220': [u'Determine the encoding of text in Python', [u'python', u'encoding', u'text-files'], 111034]}
# {u'16970982': [u'Find unique rows in numpy.array', [u'python', u'arrays', u'numpy', u'unique'], 52098]}
# {u'3085696': [u'Adding a scrollbar to a group of widgets in Tkinter', [u'python', u'tkinter'], 33961]}
# {u'3044580': [u'Multiprocessing vs Threading Python', [u'python', u'multithreading', u'multiprocessing'], 182431]}
# {u'3437059': [u"Does Python have a string 'contains' substring method?", [u'python', u'string', u'substring', u'contains'], 2138167]}
# {u'1747817': [u'Create a dictionary with list comprehension in Python', [u'python', u'dictionary', u'list-comprehension', u'language-features', u'dict-comprehension'], 519730]}
# {u'5458048': [u'How to make a Python script standalone executable to run without ANY dependency?', [u'python', u'executable'], 448853]}
# {u'127803': [u'How to parse an ISO 8601-formatted date?', [u'python', u'parsing', u'datetime', u'iso8601', u'rfc3339'], 229542]}
# {u'1720421': [u'How to concatenate two lists in Python?', [u'python', u'list'], 1147012]}
# {u'136097': [u'What is the difference between @staticmethod and @classmethod in Python?', [u'python', u'oop', u'methods', u'python-decorators'], 467049]}
# {u'17330160': [u'How does the @property decorator work?', [u'python', u'properties', u'decorator', u'python-decorators', u'python-internals'], 283586]}
# {u'2580136': [u'Does Python support short-circuiting?', [u'python', u'short-circuiting'], 54331]}
# {u'11536764': [u'How to fix \u201cAttempted relative import in non-package\u201d even with __init__.py', [u'python', u'python-import'], 286377]}
# {u'47789': [u'Generator Expressions vs. List Comprehension', [u'python', u'list-comprehension', u'generator'], 98579]}
# {u'14853243': [u"Parsing XML with namespace in Python via 'ElementTree'", [u'python', u'xml', u'xml-parsing', u'elementtree'], 73147]}
# {u'2386714': [u'Why is \u201cimport *\u201d bad?', [u'python', u'python-import'], 27974]}
# {u'4015417': [u'Python class inherits object', [u'python', u'class', u'object', u'inheritance'], 177949]}
# {u'519633': [u'Lazy Method for Reading Big File in Python?', [u'python', u'file-io', u'generator'], 150238]}
# {u'517923': [u'What is the best way to remove accents in a Python unicode string?', [u'python', u'python-3.x', u'unicode', u'python-2.x', u'diacritics'], 139344]}
# {u'9189172': [u"Why doesn't calling a Python string method do anything unless you assign its output?", [u'python', u'string', u'replace'], 96398]}
# {u'26313520': [u'Find if 24 hrs have passed between datetimes - Python', [u'python', u'datetime', u'timezone'], 5876]}
# {u'14262433': [u'\u201cLarge data\u201d work flows using pandas', [u'python', u'mongodb', u'pandas', u'hdf5', u'large-data'], 188008]}
# {u'16981921': [u'Relative imports in Python 3', [u'python', u'python-3.x', u'python-import'], 187206]}
# {u'1756096': [u'Understanding Generators in Python', [u'python', u'generator'], 83556]}
# {u'13905741': [u'Accessing class variables from a list comprehension in the class definition', [u'python', u'python-3.x', u'scope', u'list-comprehension', u'python-internals'], 8957]}
# {u'8009882': [u'How to read large file, line by line in python', [u'python', u'file-read'], 577745]}
# {u'8049520': [u'Web-scraping JavaScript page with Python', [u'python', u'web-scraping', u'urlopen'], 92763]}
# {u'189645': [u'How to break out of multiple loops in Python?', [u'python', u'break', u'control-flow'], 213579]}
# {u'1988804': [u'What is memoization and how can I use it in Python?', [u'python', u'memoization'], 104627]}
# {u'8023306': [u'Get key by value in dictionary', [u'python', u'dictionary'], 671916]}
# {u'40208051': [u'Selenium using Python - Geckodriver executable needs to be in PATH', [u'python', u'selenium', u'firefox', u'selenium-firefoxdriver', u'geckodriver'], 189844]}
# {u'183853': [u"In Python 2, what is the difference between '/' and '//' when used for division?", [u'python', u'math', u'syntax', u'operators'], 271892]}
# {u'12419198': [u'Python subprocess readlines() hangs', [u'python', u'subprocess'], 17737]}
# {u'890128': [u'Why are Python lambdas useful? [closed]', [u'python', u'function', u'lambda', u'closures'], 422434]}
# {u'625083': [u'Python __init__ and self what do they do?', [u'python', u'oop'], 688523]}
# {u'845058': [u'How to get line count cheaply in Python?', [u'python', u'text-files', u'line-count'], 493327]}
# {u'19151': [u'Build a Basic Python Iterator', [u'python', u'object', u'iterator'], 248653]}
# {u'6159900': [u'Correct way to write line to file?', [u'python', u'file-io'], 1389441]}
# {u'474528': [u'What is the best way to repeatedly execute a function every x seconds in Python?', [u'python', u'timer'], 187699]}
# {u'575196': [u'In Python, why can a function modify some arguments as perceived by the caller, but not others?', [u'python'], 78818]}
# {u'15526996': [u'IPython Notebook locale error [duplicate]', [u'python', u'python-2.7', u'locale', u'ipython', u'ipython-notebook'], 28175]}
# {u'3906137': [u"Why can't I call read() twice on an open file?", [u'python', u'io'], 44062]}
# {u'1466000': [u'python open built-in function: difference between modes a, a+, w, w+, and r+?', [u'python'], 205988]}
# {u'1191374': [u"Using module 'subprocess' with timeout", [u'python', u'multithreading', u'timeout', u'subprocess'], 190548]}
# {u'2812520': [u'pip: dealing with multiple Python versions?', [u'python', u'pip'], 241784]}
# {u'6294179': [u'How to find all occurrences of an element in a list?', [u'python', u'list'], 182329]}
# {u'123198': [u'How do I copy a file in python?', [u'python', u'file', u'copy', u'filesystems', u'copyfile'], 957004]}
# {u'306400': [u'How to randomly select an item from a list?', [u'python', u'list', u'random'], 785938]}
# {u'9535954': [u'Printing Lists as Tabular Data', [u'python'], 228725]}
# {u'5466451': [u'How can I print literal curly-brace characters in python string and also use .format on it?', [u'python', u'string', u'format', u'string-formatting', u'curly-braces'], 175960]}
# {u'526125': [u'Why is python ordering my dictionary like so? [duplicate]', [u'python', u'dictionary'], 39866]}
# {u'472000': [u'Usage of __slots__?', [u'python', u'slots'], 113547]}
# {u'6667201': [u'How to define a two-dimensional array in Python', [u'python', u'matrix', u'syntax-error'], 1323587]}
# {u'635483': [u'What is the best way to implement nested dictionaries?', [u'python', u'data-structures', u'dictionary', u'mapping', u'autovivification'], 78723]}
# {u'1816958': [u"Can't pickle <type 'instancemethod'> when using multiprocessing Pool.map()", [u'python', u'multithreading', u'multiprocessing', u'pickle', u'pool'], 86995]}
# {u'13905741': [u'Accessing class variables from a list comprehension in the class definition', [u'python', u'python-3.x', u'scope', u'list-comprehension', u'python-internals'], 8957]}
# {u'5997027': [u'Python rounding error with float numbers [duplicate]', [u'python'], 16729]}
# {u'2921847': [u'What does the Star operator mean? [duplicate]', [u'python', u'syntax', u'parameter-passing', u'identifier', u'kwargs'], 103791]}
# {u'4383571': [u'Importing files from different folder', [u'python', u'importerror', u'python-import'], 474156]}
# {u'710551': [u"'import module' or 'from module import'", [u'python', u'python-import'], 73974]}
# {u'4289331': [u'Python: Extract numbers from a string', [u'python', u'regex', u'string', u'numbers'], 415088]}
# {u'17466561': [u'Best way to structure a tkinter application', [u'python', u'tkinter'], 64422]}
# {u'21553327': [u'Why is \u201cexcept: pass\u201d a bad programming practice?', [u'python', u'exception', u'exception-handling', u'error-handling', u'try-catch'], 79613]}
# {u'6116978': [u'How to replace multiple substrings of a string?', [u'python', u'text', u'replace'], 171900]}
# {u'1335507': [u'Keyboard input with timeout in Python', [u'python', u'timeout', u'keyboard-input'], 44449]}
# {u'988228': [u'Convert a String representation of a Dictionary to a dictionary?', [u'python', u'string', u'dictionary'], 393160]}
# {u'112698': [u'py2exe - generate single executable file', [u'python', u'packaging', u'py2exe'], 121550]}
# {u'6318156': [u'Adding Python Path on Windows 7', [u'python', u'windows', u'python-2.7', u'path'], 387712]}
# {u'39980323': [u'Are dictionaries ordered in Python 3.6+?', [u'python', u'python-3.x', u'dictionary', u'python-internals', u'python-3.6'], 19352]}
# {u'1653970': [u'Does Python have an ordered set?', [u'python', u'set'], 157533]}
# {u'11269575': [u'How to hide output of subprocess in Python 2.7', [u'python', u'python-2.7', u'subprocess', u'espeak'], 125378]}
# {u'4856717': [u"Javascript equivalent of Python's zip function", [u'javascript', u'python', u'functional-programming', u'transpose'], 41549]}
# {u'2464959': [u"What's the u prefix in a Python string?", [u'python', u'syntax'], 98116]}
# {u'5434891': [u'Iterate a list as pair (current, next) in Python', [u'python'], 29054]}
# {u'6618002': [u'Python @property versus getters and setters', [u'python', u'properties', u'getter-setter'], 336557]}
# {u'237079': [u'How to get file creation & modification date/times in Python?', [u'python', u'file'], 457887]}
# {u'2988017': [u'String comparison in Python: is vs. == [duplicate]', [u'python', u'string', u'comparison', u'equality'], 776239]}
# {u'12065885': [u'Filter dataframe rows if value in column is in a set list of values', [u'python', u'pandas', u'dataframe'], 154361]}
# {u'19339': [u'Transpose/Unzip Function (inverse of zip)?', [u'python', u'list', u'matrix', u'unzip', u'transpose'], 87714]}
# {u'492387': [u'IndentationError: unindent does not match any outer indentation level', [u'python', u'indentation'], 754070]}
# {u'13081532': [u'Return JSON response from Flask view', [u'python', u'json', u'flask'], 191550]}
# {u'25445439': [u"What does \u201cSyntaxError: Missing parentheses in call to 'print'\u201d mean in Python?", [u'python', u'python-3.x'], 485427]}
# {u'5595425': [u'What is the best way to compare floats for almost-equality in Python?', [u'python', u'floating-point'], 93228]}
# {u'1637807': [u'Modifying list while iterating [duplicate]', [u'python', u'list', u'iterator', u'loops'], 61789]}

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd

df = pd.DataFrame()
# Out:
# /Users/Shared/anaconda3/envs/pytn/lib/python2.7/site-packages/pandas/core/nanops.py:39: UserWarning: The installed version of bottleneck 0.8.0 is not supported in pandas and will be not be used
# The minimum supported version is 1.0.0
#
#   ver=ver, min_ver=_MIN_BOTTLENECK_VERSION), UserWarning)

# %%
df
# Out:
#                                                 100003 1009860 101268  \
# 0                                                  NaN     NaN    NaN
# 1                                                  NaN     NaN    NaN
# 2                                                  NaN     NaN    NaN
# 3                                                  NaN     NaN    NaN
# 4                                                  NaN     NaN    NaN
# 5                                                  NaN     NaN    NaN
# 6                                                  NaN     NaN    NaN
# 7                                                  NaN     NaN    NaN
# 8                                                  NaN     NaN    NaN
# 9                                                  NaN     NaN    NaN
# 10                                                 NaN     NaN    NaN
# 11                                                 NaN     NaN    NaN
# 12                                                 NaN     NaN    NaN
# 13                                                 NaN     NaN    NaN
# 14                                                 NaN     NaN    NaN
# 15                                                 NaN     NaN    NaN
# 16                                                 NaN     NaN    NaN
# 17                                                 NaN     NaN    NaN
# 18                                                 NaN     NaN    NaN
# 19                                                 NaN     NaN    NaN
# 20                                                 NaN     NaN    NaN
# 21   [What are metaclasses in Python?, [python, oop...     NaN    NaN
# 22                                                 NaN     NaN    NaN
# 23                                                 NaN     NaN    NaN
# 24                                                 NaN     NaN    NaN
# 25                                                 NaN     NaN    NaN
# 26                                                 NaN     NaN    NaN
# 27                                                 NaN     NaN    NaN
# 28                                                 NaN     NaN    NaN
# 29                                                 NaN     NaN    NaN
# ..                                                 ...     ...    ...
# 220                                                NaN     NaN    NaN
# 221                                                NaN     NaN    NaN
# 222                                                NaN     NaN    NaN
# 223                                                NaN     NaN    NaN
# 224                                                NaN     NaN    NaN
# 225                                                NaN     NaN    NaN
# 226                                                NaN     NaN    NaN
# 227                                                NaN     NaN    NaN
# 228                                                NaN     NaN    NaN
# 229                                                NaN     NaN    NaN
# 230                                                NaN     NaN    NaN
# 231                                                NaN     NaN    NaN
# 232                                                NaN     NaN    NaN
# 233                                                NaN     NaN    NaN
# 234                                                NaN     NaN    NaN
# 235                                                NaN     NaN    NaN
# 236                                                NaN     NaN    NaN
# 237                                                NaN     NaN    NaN
# 238                                                NaN     NaN    NaN
# 239                                                NaN     NaN    NaN
# 240                                                NaN     NaN    NaN
# 241                                                NaN     NaN    NaN
# 242                                                NaN     NaN    NaN
# 243                                                NaN     NaN    NaN
# 244                                                NaN     NaN    NaN
# 245                                                NaN     NaN    NaN
# 246                                                NaN     NaN    NaN
# 247                                                NaN     NaN    NaN
# 248                                                NaN     NaN    NaN
# 249                                                NaN     NaN    NaN
#
#     10434599 104420 1059559 107705 1101750 110259  \
# 0        NaN    NaN     NaN    NaN     NaN    NaN
# 1        NaN    NaN     NaN    NaN     NaN    NaN
# 2        NaN    NaN     NaN    NaN     NaN    NaN
# 247      NaN    NaN     NaN    NaN     NaN    NaN
# 248      NaN    NaN     NaN    NaN     NaN    NaN
# 249      NaN    NaN     NaN    NaN     NaN    NaN
#
#                                               11269575   ...   9189172  \
# 0                                                  NaN   ...       NaN
# 1                                                  NaN   ...       NaN
# 2                                                  NaN   ...       NaN
# 3                                                  NaN   ...       NaN
# 4                                                  NaN   ...       NaN
# 5                                                  NaN   ...       NaN
# 6                                                  NaN   ...       NaN
# 7                                                  NaN   ...       NaN
# 8                                                  NaN   ...       NaN
# 9                                                  NaN   ...       NaN
# 10                                                 NaN   ...       NaN
# 11                                                 NaN   ...       NaN
# 12                                                 NaN   ...       NaN
# 13                                                 NaN   ...       NaN
# 14                                                 NaN   ...       NaN
# 15                                                 NaN   ...       NaN
# 16                                                 NaN   ...       NaN
# 17                                                 NaN   ...       NaN
# 18                                                 NaN   ...       NaN
# 19                                                 NaN   ...       NaN
# 20                                                 NaN   ...       NaN
# 21                                                 NaN   ...       NaN
# 22                                                 NaN   ...       NaN
# 23                                                 NaN   ...       NaN
# 24                                                 NaN   ...       NaN
# 25                                                 NaN   ...       NaN
# 26                                                 NaN   ...       NaN
# 27                                                 NaN   ...       NaN
# 28                                                 NaN   ...       NaN
# 29                                                 NaN   ...       NaN
# ..                                                 ...   ...       ...
# 220                                                NaN   ...       NaN
# 221                                                NaN   ...       NaN
# 222                                                NaN   ...       NaN
# 223                                                NaN   ...       NaN
# 224                                                NaN   ...       NaN
# 225                                                NaN   ...       NaN
# 226                                                NaN   ...       NaN
# 227                                                NaN   ...       NaN
# 228                                                NaN   ...       NaN
# 229                                                NaN   ...       NaN
# 230                                                NaN   ...       NaN
# 231                                                NaN   ...       NaN
# 232                                                NaN   ...       NaN
# 233                                                NaN   ...       NaN
# 234                                                NaN   ...       NaN
# 235                                                NaN   ...       NaN
# 236  [How to hide output of subprocess in Python 2....   ...       NaN
# 237                                                NaN   ...       NaN
# 238                                                NaN   ...       NaN
# 239                                                NaN   ...       NaN
# 240                                                NaN   ...       NaN
# 241                                                NaN   ...       NaN
# 242                                                NaN   ...       NaN
# 243                                                NaN   ...       NaN
# 244                                                NaN   ...       NaN
# 245                                                NaN   ...       NaN
# 246                                                NaN   ...       NaN
# 247                                                NaN   ...       NaN
# 248                                                NaN   ...       NaN
# 249                                                NaN   ...       NaN
#
#     9264763 931092                                             952914 9535954  \
# 0       NaN    NaN                                                NaN     NaN
# 1       NaN    NaN                                                NaN     NaN
# 2       NaN    NaN                                                NaN     NaN
# 3       NaN    NaN                                                NaN     NaN
# 4       NaN    NaN                                                NaN     NaN
# 5       NaN    NaN                                                NaN     NaN
# 6       NaN    NaN                                                NaN     NaN
# 7       NaN    NaN                                                NaN     NaN
# 8       NaN    NaN                                                NaN     NaN
# 9       NaN    NaN                                                NaN     NaN
# 10      NaN    NaN  [Making a flat list out of list of lists in Py...     NaN
# 11      NaN    NaN                                                NaN     NaN
# 12      NaN    NaN                                                NaN     NaN
# 13      NaN    NaN                                                NaN     NaN
